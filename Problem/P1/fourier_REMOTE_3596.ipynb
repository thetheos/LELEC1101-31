# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go

#A = 5
#y = A/2*np.ones(10000)
#z = np.zeros(10000)
x = np.linspace(0,0.1,10000)
V_max = 10
V_min = -5
f = 100

h = np.ones(10000)*(V_max +V_min)/2


for i in range(1,1000):
    #y += -4*A*np.cos((2*i-1)*2*np.pi*1000*x)/((2*i-1)**2*np.pi**2)
    #z += 8*A*np.sin((2*i+1)*np.pi/2)*np.sin((2*i+1)*2*np.pi*1000*x)/((2*i+1)*np.pi)**2
    h -= 4*(V_max-V_min)*np.cos((2*i-1)*2*np.pi*f*x)/(np.pi*(2*i-1))**2 

fig = go.Figure(data=go.Scatter(x=x,y=h))
fig.show(rendered="jupyterlab")
    
#plt.plot(x,z)
#plt.show()
